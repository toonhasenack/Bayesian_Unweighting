# %%
from src.Functionality import *
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
chi = np.random.random(100)*0.5 + 0.5

# %%
u = Unweight(None, (10,chi))
u.reweight()
N,E,Nopt = u.optimize(0.1)
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 84.94it/s]

# %%
fig = plt.figure()
ax = plt.axes(xscale="log")
ax.axvline(Nopt, c="r", linestyle=":")
ax.plot(N,E)
ax.set_xlabel(r"Replica Number $N'_{rep}$",size=18)
ax.set_ylabel(r"Entropy $H$",size=18)
# Out:
# Text(0, 0.5, 'Entropy $H$')

# %%
u.unweight(Nopt)
print(u.unweights)
# Out:
# [1. 0. 3. 1. 3. 3. 0. 5. 4. 1. 4. 1. 0. 0. 3. 0. 1. 0. 1. 0. 0. 1. 2. 0.
#  0. 0. 0. 1. 4. 5. 3. 2. 2. 0. 5. 5. 0. 0. 1. 1. 1. 2. 1. 0. 1. 0. 0. 4.
#  0. 1. 0. 0. 1. 0. 0. 4. 4. 1. 3. 0. 2. 3. 0. 0. 2. 4. 1. 0. 1. 3. 2. 0.
#  0. 0. 2. 0. 0. 0. 0. 3. 0. 5. 2. 2. 0. 0. 0. 1. 1. 0. 1. 4. 3. 3. 0. 4.
#  0. 0. 0. 0.]
